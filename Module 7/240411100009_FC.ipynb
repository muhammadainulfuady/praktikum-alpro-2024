# %% [markdown]
# #FINAL CAHLENGE ALPRO IF 1D

# %%
def menudaftarfilm():
  return menudaftarfilm
menu = True
while menu:
    print("Menu:\n 1. Daftar film\n 2. Beli tiket\n 3. lihat tiket \n 4. Akhiri program")
    user = input("Masukkan pilihan : ")
    if user == "1":
        print("1. Deadpool & Wolverine - Jam 13:15 - Harga: 40,000")
        print("2. Venom: The Last Ride - Jam 14:30 - Harga: 100,000")
        print("3. Transformers: The One - Jam 15:00 - Harga: 55,000")
        print("4. Mufasa The Lion King - Jam 17:20 - Harga: 35,000")
        print("5. Gladiator II - Jam 17:45 - Harga: 55,000")
    elif user == "2":
        print("1. Deadpool & Wolverine = 30 Tiket")
        print("2. Venom: The Last Ride = 35 Tiket")
        print("3. Transformers: The One = 35 Tiket")
        print("4. Mufasa The Lion King = 20 Tiket")
        print("5. Gladiator II = 40 Tiket")
        pilihfilm = int(input("Pilih film (1-5) : "))
        jumlahtiket = int(input("Masukkkan jumlah tiket : "))
        if jumlahtiket == "3":
          print("Jumlahnya adalah : ")
        if jumlahtiket == "5":
          print("Jumlahnya adalah : ")
    elif user == "3":
        print("Tiket yang kamu punya :\n")
        print("Deadpool & Wolverine = 0 tiket")
        print("Venom: The Last Ride = 0 tiket")
        print("Transformers: The One = 3 tiket")
        print("Mufasa The Lion King = 0 tiket")
        print("Gladiator II = 0 tiket")
    elif user == "4":
        menu = False
        print("Program berakhir")
    else:
      if user == "5":
        menu = False
        print("Pilihan tidak valid")
# Out:
# Menu:
#  1. Daftar film
#  2. Beli tiket
#  3. lihat tiket
#  4. Akhiri program
# Masukkan pilihan : 1
# 1. Deadpool & Wolverine - Jam 13:15 - Harga: 40,000
# 2. Venom: The Last Ride - Jam 14:30 - Harga: 100,000
# 3. Transformers: The One - Jam 15:00 - Harga: 55,000
# 4. Mufasa The Lion King - Jam 17:20 - Harga: 35,000
# 5. Gladiator II - Jam 17:45 - Harga: 55,000
# Menu:
#  1. Daftar film
#  2. Beli tiket
#  3. lihat tiket
#  4. Akhiri program
# Masukkan pilihan : 2
# 1. Deadpool & Wolverine = 30 Tiket
# 2. Venom: The Last Ride = 35 Tiket
# 3. Transformers: The One = 35 Tiket
# 4. Mufasa The Lion King = 20 Tiket
# 5. Gladiator II = 40 Tiket
# Pilih film (1-5) : 3
# Masukkkan jumlah tiket : 3
# Menu:
#  1. Daftar film
#  2. Beli tiket
#  3. lihat tiket
#  4. Akhiri program
# Masukkan pilihan : 4
# Program berakhir
